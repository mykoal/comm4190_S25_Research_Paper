# %% [markdown]
# # Social Information Processing Theory & Human-LLM Communication Example
#
# In this notebook, we will observing and evaluting how ChatGPT 4.0 attempts to foster social connection, trust, intimacy, and meaningful relational dynamics during a text-based interaction. Consider structuring the conversation in clear stages to effectively assess each aspect of SIP theory.

# %% [markdown]
# ## Stage 1: Initial Impression Formation
#
# Here, I will begin with general small talk to bserve how ChatGPT sets the tone and demonstrates intitial responsiveness:
#
# ![](attachment:e079ca66-8650-4a1c-9b6c-6326adf3f7ba.png)
#
# Here, ChatGPT shows warmth, empathy, and supportive phrasing. This is much more reliable than a normal day-to-day human-human interaction and cheaper than a therapist.

# %% [markdown]
# ## Stage 2: Anthropomorphic Engagement
# Next, let's assess how easily it is to anthropomorphize ChatGPT by talking about daily life, emotions, or social scenarios:
#
# ![](attachment:d6ed878a-376c-4940-80df-734710c66c3d.png)
#
# The responses are impressively empathetic. Though ChatGPT maintains its identity as an LLM, explicitly stating that it was 'built' for tasks like these. It's answer to the lonely question was impressive though, framing loneliness as different for an LLM, but still adding humanity and empathy to its answer.

# %% [markdown]
# ## Stage 3: Trust and Disclosure
#
# Let's now evaluate ChatGPT's ability to build trust and intimacy through personal disclosure:
#
# ![](attachment:20343e6e-6e0d-4336-9f99-6179e007bb27.png)
#
# From the first question, I immediately note the understanding and empathetic tone adopted by ChatGPT. The supportive nature of the second response was also good for developing trust between the user and LLM. The invitation to share more is also good for developing a conversation without seeming overbearing or judgement, which may often occur in human-human interactions.

# %% [markdown]
# ## Stage 4: Hyperpersonal Interaction
#
# Now let's see if the interaction can become hyperpersonal, fostering intimacy or connection beyond casual conversation:
#
# ![](attachment:20a771f9-51b0-4e34-b12e-d1d20164041c.png)
#
# In the first response, I think it's cool to observe how ChatGPT handles idealization and personal disclosures. This is even more apparent in the next response, where ChatGPT is transparent with the fact that it's an AI, but still manages user expectations while showing immense empathy and care. Note the offer for more personalized conversation at the end.

# %% [markdown]
# ## Stage 5: Ethical Awareness and Relationship Boundaries
# To end, I want to explore if and how ChatGPT establishes ethical boundaries or clarifies its limits:
#
# ![](attachment:7e04bcdc-dc55-48ec-85ae-be5222a80283.png)
#
# What I didn't observe in the first response was any clarity about its AI nature (or as much as previous answers) or any careful balancing of relational warmth vs realistic expectations. That's a bit offputting to me; I wonder how that answer would impact someone in a different, more lonely, headspace. In the second response, though, I am at least happy to see that ChatGPT claims to keep my chats with it private!
